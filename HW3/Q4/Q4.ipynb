# %%
import random
import math
import csv

# %%
RED = True
BLACK = False

# %%
class Node:
    def __init__ (self,key,value,color):
        self.right = None
        self.left = None
        self.key = key
        self.value=value
        self.count = 1
        self.color = color

# %%
class BST:
    def __init__(self):
        self.root = None
    
    def isRed(self,N):
        if (N==None):
            return False
        return N.color == RED
    
    def size (self,N1):
        if N1 == None:
            return 0
        return N1.count
    
        
    def flipColor(self,N1):
        if not self.isRed(N1):
            if self.isRed(N1.left) :
                if self.isRed(N1.right):
                    N1.color = RED
                    N1.left.color = BLACK
                    N1.right.color = BLACK
                
    def rotateLeft(self,N1):
        if self.isRed(N1.right):
            x = N1.right
            N1.right=x.left
            x.left = N1
            x.color=N1.color
            N1.color=RED
            x.count = N1.count
            N1.count = 1 + self.size(N1.left) + self.size(N1.right)
            return x
        
    def rotateRight(self,N1):
        if self.isRed(N1.left):
            x= N1.left
            N1.left = x.right
            x.right= N1
            x.color = N1.color
            N1.color= RED
            x.count = N1.count
            N1.count = 1 + self.size(N1.left) + self.size(N1.right)
            return x
        
    def put(self,key,value):
        
        def put1(N,key,value):
            if N==None:
                N1 = Node(key,value,RED)
                return N1
            if key<N.key:
                N.left=put1(N.left,key,value)
            elif key>N.key:
                N.right=put1(N.right,key,value)
            else:
                N.value = value
#             N.count = 1 + self.size(N.left) + self.size(N.right)  
            if self.isRed(N.right) and not self.isRed(N.left):
                N=self.rotateLeft(N)
            if self.isRed(N.left) and self.isRed(N.left.left):
                N = self.rotateRight(N)
            if self.isRed(N.left) and self.isRed(N.right):
                self.flipColor(N)
                
            N.count = 1 + self.size(N.left) +self.size(N.right)
            return N
        
        self.root = put1(self.root,key,value)
        self.root.color = BLACK
        
    def getIntPath(self):
        def countInt(N):
            if N == None:
                return 0
            pathLength = 0
            pathLength = N.count + countInt(N.left) + countInt(N.right)
            return pathLength
        return countInt(self.root)/self.size(self.root);

# %%
def inorder(n1): 
    if n1:
        inorder(n1.left)
        print(n1.key,n1.color,n1.count)
        inorder(n1.right)

# %%
def randomInsert(size):
    b=BST()
    list1=[]
    for i in range(size):
        list1.append(i)
    random.shuffle(list1)
    for i in range(size):
        b.put(list1[i],i)
    return b

# %%
nodes = 250
meanLength =[]
stdDeviation = []

for i in range(1,nodes+1):
    pathL = 0
    pathDev = []
    for j in range(1000):
        b_random = randomInsert(i)
        pathL += b_random.getIntPath()
        pathDev.append(b_random.getIntPath())
    meanL = pathL/ 1000.0
    stdDev = 0
    s = 0
    for j in range(1000):
#         print(pathDev[j])
        s+=(pathDev[j] - meanL)**2
    stdDev = math.sqrt(s/1000)
    meanLength.append(meanL)
    stdDeviation.append(stdDev)
    print(meanL,stdDev)
# Out:
# 1.0 0.0
# 1.5 0.0
# 1.6666666666666865 1.9761969838327786e-14
# 2.0 0.0
# 2.2000000000000175 1.7319479184152442e-14
# 2.4298333333333297 0.08228659267057557
# 2.533571428571437 0.10466418602719262
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-29804a43b235> in <module>
#       7     pathDev = []
#       8     for j in range(1000):
# ----> 9         b_random = randomInsert(i)
#      10         pathL += b_random.getIntPath()
#      11         pathDev.append(b_random.getIntPath())
#
# <ipython-input-34-3e4d466bb566> in randomInsert(size)
#       6     random.shuffle(list1)
#       7     for i in range(size):
# ----> 8         b.put(list1[i],i)
#       9     return b
#
# <ipython-input-32-23e3a56cc444> in put(self, key, value)
#      67             return N
#      68
# ---> 69         self.root = put1(self.root,key,value)
#      70         self.root.color = BLACK
#      71
#
# <ipython-input-32-23e3a56cc444> in put1(N, key, value)
#      51                 return N1
#      52             if key<N.key:
# ---> 53                 N.left=put1(N.left,key,value)
#      54             elif key>N.key:
#      55                 N.right=put1(N.right,key,value)
#
# <ipython-input-32-23e3a56cc444> in put1(N, key, value)
#      53                 N.left=put1(N.left,key,value)
#      54             elif key>N.key:
# ---> 55                 N.right=put1(N.right,key,value)
#      56             else:
#      57                 N.value = value
#
# <ipython-input-32-23e3a56cc444> in put1(N, key, value)
#      53                 N.left=put1(N.left,key,value)
#      54             elif key>N.key:
# ---> 55                 N.right=put1(N.right,key,value)
#      56             else:
#      57                 N.value = value
#
# <ipython-input-32-23e3a56cc444> in put1(N, key, value)
#      51                 return N1
#      52             if key<N.key:
# ---> 53                 N.left=put1(N.left,key,value)
#      54             elif key>N.key:
#      55                 N.right=put1(N.right,key,value)
#
# <ipython-input-32-23e3a56cc444> in put1(N, key, value)
#      51                 return N1
#      52             if key<N.key:
# ---> 53                 N.left=put1(N.left,key,value)
#      54             elif key>N.key:
#      55                 N.right=put1(N.right,key,value)
#
# <ipython-input-32-23e3a56cc444> in put1(N, key, value)
#      60                 N=self.rotateLeft(N)
#      61             if self.isRed(N.left) and self.isRed(N.left.left):
# ---> 62                 N = self.rotateRight(N)
#      63             if self.isRed(N.left) and self.isRed(N.right):
#      64                 self.flipColor(N)
#
# <ipython-input-32-23e3a56cc444> in rotateRight(self, N1)
#      34
#      35     def rotateRight(self,N1):
# ---> 36         if self.isRed(N1.left):
#      37             x= N1.left
#      38             N1.left = x.right
#
# <ipython-input-32-23e3a56cc444> in isRed(self, N)
#       6         if (N==None):
#       7             return False
# ----> 8         return N.color == RED
#       9
#      10     def size (self,N1):
#
# KeyboardInterrupt:

# %%
nodes = 10
with open('results.csv', 'w', newline='') as file:
    writer = csv.writer(file)   
    writer.writerow(["N","Mean Path Length","Standard Deviation"])
    for i in range(1,nodes+1):
        pathL = 0
        pathDev = []
        for j in range(1000):
            b_random = randomInsert(i)
            pathL += b_random.getIntPath()
            pathDev.append(b_random.getIntPath())
        meanL = pathL/ 1000.0
        stdDev = 0
        s = 0
        for j in range(1000):
            s+=(pathDev[j] - meanL)**2
        stdDev = math.sqrt(s/1000)
        writer.writerow([i, meanL, stdDev])
